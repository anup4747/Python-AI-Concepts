# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# 10 to 60 random 50
# x = np.random.randint(10,60,(50))
x = [12 ,22 ,32 ,36 ,50 ,34, 18 ,59 ,30 ,19 ,54 ,48 ,56 ,47 ,48 ,30 ,29 ,33 ,12 ,26 ,19 ,31 ,23 ,44 ,45 ,37 ,33 ,46 ,49 ,43 ,32 ,44 ,48 ,57 ,21 ,23 ,41 ,29 ,45 ,26 ,58 ,25 ,45 ,45 ,13 ,38 ,18 ,24 ,11 ,12]
# print(x)
plt.hist(x , color = "b", edgecolor = "r",align = "mid", label = "python")
# plt.hist(x , color = "b", edgecolor = "r",histtype = "step")
# plt.hist(x , color = "b", edgecolor = "r",histtype = "stepfilled")
# plt.hist(x , color = "b", edgecolor = "r",histtype = "barstacked")
# plt.hist(x , color = "b", edgecolor = "r",orientation = "horizontal")
# plt.hist(x , color = "b", edgecolor = "r",orientation = "vertical")
# plt.hist(x ,"auto",(0,200), edgecolor = "r")
plt.title("hist")
plt.xlabel("python")
plt.ylabel("No.")

# plt.axvline(45, color = "g" , label = "line")
# plt.grid()
plt.legend()
plt.show()
